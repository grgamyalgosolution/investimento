# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import os
import numpy as np
from main import GabrielInvestimentos
pd.set_option('display.max_rows', 300)

# %% [markdown]
# # Selic

# %% [markdown]
# ## Definição:

# %% [markdown]
# A taxa Selic, ou Sistema Especial de Liquidação e Custódia, é a taxa básica de juros da economia brasileira. Ela é definida pelo Banco Central por meio do Copom e serve como: <br>
#
# <ul>
#     <li> referência para todos os juros do país
#     <li> principal ferramenta para controlar a inflação
# </ul>
#
# <br><br><br>
#
# O que ela afeta?
# <ul>
#     <li> CDI
#     <li> CDB, LCI, LCA
#     <li> Tesouro direto
#     <li> Financiamentos
#     <li> Cartão de crédito
#     <li> Atividade econômica
# </ul>
#
#
# <br><br><br>
#
# Como investir:
# <ul>
#     <li>Selic em alta 📈;
#     <ul>
#         <li> Crédito caro
#         <li> Economia desacelera
#         <li> Inflação tende a cair
#         <li> <b>RENDA FIXA RENDE MAIS</b>
#     </ul>
#     <li>Selic em baixa 📉;
#     <ul>
#         <li> Crédito barato
#         <li> Economia aquece
#         <li> Inflação pode subir
#         <li> <b>RENDA FIXA RENDE MENOS</b>
#     </ul>
#
#
# </ul>
#
#
# <br><br><br>
# | Termo               | O que é                        | Quem define        | Natureza                  |
# | ------------------- | ------------------------------ | ------------------ | ------------------------- |
# | $\text{Selic}_{\text{meta}} = r_{a.a.}$     | Taxa-alvo de juros             | Copom (BC)   a cada 45 dias      | **Meta anual**            |
# | Selic **overnight** | Taxa efetiva do mercado        | Mercado + BC       | **Observada diariamente** |
# | Selic **diária**    | Forma operacional da overnight | Mercado            | **Taxa diária**           |
# | Selic **anual**     | Annualização da diária         | Cálculo matemático | **Taxa equivalente a.a.** |

# %% [markdown]
# ## Equação:

# %% [markdown]
# A taxa selic diária, ou selic overnight, $\text{Selic}_d$ é calculada como a média ponderada por volume:
#
#
# $$\text{Selic}_d = \frac{\sum^{N}_{i=1}(V_i . r_i)}{\sum^{N}_{i=1}V_i}$$
#
#
# Onde:<br>
# $V_i$ = volume financeiro da operação $i$; <br>
# $r_i$ = taxa de juros da operação $i$; <br>
# $V_i$ = número de operações no dia. <br>

# %% [markdown]
# A taxa selic anual, ou selic meta, $\text{Selic}_{a.a.}$ é a capitalização composta da $\text{Selic}_d$
#
# <br>
#
# $$\text{Selic}_d = \left(\prod^{D}_{d=1}(1 + \text{Selic}_d)\right) - 1 $$
#
#
# Onde:<br>
#
# $D$ = número de dias úteis no ano. <br>

# %% [markdown]
# # CDI

# %% [markdown]
# ## Definição

# %% [markdown]
# O CDI, ou Certificado de Depósito Interbancário, é a taxa média das operações overnight entre bancos, sem títulos públicos, registradas na B3.

# %% [markdown]
# ## Equação:

# %% [markdown]
# O CDI diário, $\text{CDI}_d$ é calculado como a média ponderada por volume:
#
#
# $$\text{CDI}_d = \frac{\sum^{N}_{i=1}(V_i . r_i)}{\sum^{N}_{i=1}V_i}$$
#
#
# Onde:<br>
# $V_i$ = volume da operação interbancária $i$; <br>
# $r_i$ = taxa de juros da operação $i$; <br>
# $V_i$ = número de operações no dia. <br>

# %% [markdown]
# O CDI anual, $\text{CDI}_{a.a.}$ é a capitalização composta do $\text{CDI}_d$
#
# <br>
#
# $$\text{CDI}_d = \left(\prod^{D}_{d=1}(1 + \text{CDI}_d)\right) - 1 $$
#
#
# Onde:<br>
#
# $D$ = número de dias úteis no ano. <br>

# %% [markdown]
# ## Diferença entre CDI e Selic

# %% [markdown]
# A taxa Selic e a taxa CDI estão diretamente relacionadas, pois ambas refletem o custo do dinheiro no mercado financeiro. A Selic é a taxa básica de juros da economia brasileira, definida pelo Banco Central. Já o CDI (Certificado de Depósito Interbancário) é a taxa média dos empréstimos diários entre os bancos. Inclusive, a taxa CDI geralmente segue de perto a Selic, uma vez que o custo do dinheiro no mercado interbancário é influenciado pela taxa básica de juros.
#
# Quando o Banco Central altera a Selic, o custo do crédito e o rendimento dos investimentos em renda fixa são ajustados, impactando diretamente a taxa CDI. Portanto, uma elevação na Selic tende a aumentar a taxa CDI, enquanto uma redução na Selic tende a diminuir a taxa CDI. Essa correlação ocorre porque a Selic serve como referência para todas as demais taxas de juros do mercado, incluindo o CDI.

# %% [markdown]
# # IPCA

# %% [markdown]
# ## Definição:

# %% [markdown]
# O IPCA, ou Índice de Preços ao Consumidor Amplo, é o índice oficial da inflação no Brasil, usado para corrigir o valor de títulos como o Tesouro IPCA+. Oferece proteção contra a inflação, pois ajusta a rentabilidade do investimento com base na variação dos preços ao consumidor;

# %% [markdown]
# ## 🏆 LCI/LCA híbridas são as melhores quando?

# %% [markdown]
# Elas ganham de quase tudo quando TODAS as condições abaixo são verdadeiras:
#
# ✅ 1. Seu horizonte é longo (≥ 3–5 anos)
#
# Não precisa resgatar antes
#
# Pode ignorar oscilações
#
# ✅ 2. A taxa real está alta
#
# Exemplo:
#
# IPCA + 5,5% ou mais
#
# Isso é excelente no Brasil
#
# ✅ 3. Você quer preservar poder de compra
#
# Renda futura
#
# Patrimônio
#
# Independência financeira
#
# ✅ 4. Você valoriza isenção de IR
#
# Em prazos longos, o IR come muito retorno
#
# Aqui a LCI/LCA híbrida vence CDB e Tesouro
#
# 👉 Nesse cenário, sim: são das melhores rendas fixas possíveis.

# %% [markdown]
# # RISCO / RENDIMENTO:

# %% [markdown]
# Ótima pergunta — agora você está exatamente no **nível “investidor racional”**: aceitar **um pouco mais de risco** para ganhar **mais retorno**, sem entrar em aventura.
#
# Vou listar **investimentos com MENOS segurança que LCI/LCA**, mas que ainda são **considerados de alto nível de segurança**, e **por que rendem mais**.
#
# ---

# %% [markdown]
# ## 🟡 Regra geral (importante)

# %% [markdown]
# > **LCI/LCA são o “teto” de segurança com IR zero + FGC.**
# > Qualquer coisa que renda mais:
#
# * ❌ perde o FGC **ou**
# * ❌ assume risco de mercado **ou**
# * ❌ assume risco de crédito
#
# ---
#
# ## 🏦 1️- CDB de bancos médios (alto rating)

# %% [markdown]
# #### 📌 Por que rende mais

# %% [markdown]
# * Paga IR
# * Banco precisa competir com grandes
# * Pode pagar **110%–130% do CDI**
#
# #### 📊 Segurança

# %% [markdown]
# * ❌ Menos seguro que LCI/LCA
# * ✅ Ainda **alto nível de segurança**
# * ✅ Tem **FGC**
#
# #### 🔢 Retorno líquido típico

# %% [markdown]
# * LCI/LCA: ~90–95% CDI líquido
# * CDB 120% CDI (após IR): ~100–105% CDI líquido
#
# 📌 **Muito comum superar LCI/LCA no líquido**
#
# ---
#
# ## 🏭 2️- Debêntures incentivadas (empresas sólidas)

# %% [markdown]
# #### 📌 Por que rendem mais

# %% [markdown]
# * Não têm FGC
# * Risco de crédito corporativo
# * Prazo longo
#
# #### 📊 Segurança

# %% [markdown]
# * ✅ Empresas grandes (energia, saneamento)
# * ❌ Sem FGC
# * ⚠️ Marcação a mercado
#
# #### 🔢 Retorno típico

# %% [markdown]
# * IPCA + **6% a 8%**
# * Isento de IR
#
# 📌 **Ganham fácil de LCI/LCA híbridas se bem escolhidas**
#
# ---

# %% [markdown]
# ## 🏢 3️- Fundos de debêntures incentivadas

# %% [markdown]
# #### 📌 Por que rendem mais

# %% [markdown]
# * Carteira diversificada
# * Gestão ativa
# * Acesso a emissões melhores
#
# #### 📊 Segurança

# %% [markdown]
# * Menos risco que debênture única
# * Ainda sem FGC
# * Oscilações no curto prazo
#
# 📌 Boa relação risco/retorno
#
# ---

# %% [markdown]
# ## 🏘️ 4️⃣ CRI / CRA de alta qualidade (top tier)

# %% [markdown]
# #### 📌 Por que rendem mais

# %% [markdown]
# * Estrutura complexa
# * Risco pulverizado
# * Isentos de IR
#
# #### 📊 Segurança

# %% [markdown]
# * Sem FGC
# * Depende muito da estrutura
# * Pode ser **bem seguro** se:
#
#   * senior tranche
#   * garantias reais
#   * bons devedores
#
# 📌 **Não é para leigo**, mas paga bem
#
# ---

# %% [markdown]
# ## 📈 5️⃣ Fundos multimercado conservadores

# %% [markdown]
# #### 📌 Por que rendem mais

# %% [markdown]
# * Gestão ativa
# * Juros + arbitragem
# * Pode superar CDI
#
# #### 📊 Segurança

# %% [markdown]
# * Baixa volatilidade
# * Sem garantia
# * Risco de gestor
#
# 📌 Histórico > CDI no longo prazo
#
# ---
#
# ## ⚖️ Comparação direta (ordem de risco)

# %% [markdown]
# | Produto                  | Segurança | Retorno |
# | ------------------------ | --------- | ------- |
# | LCI/LCA                  | ⭐⭐⭐⭐⭐     | ⭐⭐      |
# | CDB médio                | ⭐⭐⭐⭐½     | ⭐⭐⭐     |
# | Debênture incent.        | ⭐⭐⭐⭐      | ⭐⭐⭐⭐    |
# | Fundo deb. incent.       | ⭐⭐⭐⭐      | ⭐⭐⭐⭐    |
# | CRI/CRA premium          | ⭐⭐⭐½      | ⭐⭐⭐⭐½   |
# | Multimercado conservador | ⭐⭐⭐½      | ⭐⭐⭐⭐    |
#
# ---
#
# ## 🧠 Estratégia profissional (muito usada)

# %% [markdown]
# > **Não trocar LCI/LCA — complementar**
#
# Exemplo típico:
#
# * 50% LCI/LCA
# * 25% debêntures incentivadas
# * 15% CDB 120% CDI
# * 10% multimercado conservador
#
# 👉 Aumenta retorno **sem explodir risco**.
#
# ---
#
# ## ⚠️ Erro comum

# %% [markdown]
# > “Se rende mais, deve ser muito arriscado”
#
# ❌ Nem sempre
# O risco aumenta **gradualmente**, não explode.
#
# ---
#
# ## ✅ Conclusão clara

# %% [markdown]
# Se você quer:
#
# * mais retorno que LCI/LCA
# * sem pular para renda variável
#
# 👉 **CDBs bons, debêntures incentivadas e fundos conservadores** são o próximo degrau lógico.

# %% [markdown]
# # Estratégia:

# %% [markdown]
# Vamos montar **uma estratégia profissional, conservadora e eficiente** usando **CDB (3 meses) + LCI + LCA**, pensada para:
#
# * **máxima segurança**
# * **respeitar o FGC**
# * **boa liquidez**
# * **ótimo retorno líquido**
# * **flexibilidade para ciclos de juros**

# %% [markdown]
# ## 🎯 Objetivo da estratégia

# %% [markdown]
# * Capital: **R$ 600.000**
# * Perfil: conservador racional
# * Preferência: **LCI/LCA**
# * CDB apenas como **instrumento tático**
# * Minimizar riscos **de crédito, liquidez e reinvestimento**
#
# ---

# %% [markdown]
# ## 🧱 Estrutura geral da carteira

# %% [markdown]
# | Classe               | %        | Valor          |
# | -------------------- | -------- | -------------- |
# | CDB (3 meses)        | **25%**  | R$ 150.000     |
# | LCI pós-fixada       | **40%**  | R$ 240.000     |
# | LCA (pós ou híbrida) | **35%**  | R$ 210.000     |
# | **Total**            | **100%** | **R$ 600.000** |
#
# ---

# %% [markdown]
# ## 🏦 1️- CDB — vencimento **3 meses** (parte tática)

# %% [markdown]
# #### 📌 Função

# %% [markdown]
# * Liquidez programada
# * Reduz risco temporal
# * Caixa para oportunidades
# * Proteção contra mudanças rápidas de juros

# %% [markdown]
# #### 🔢 Estrutura sugerida

# %% [markdown]
# * **2 bancos médios**
# * R$ 75.000 em cada
# * Taxa alvo: **115%–125% do CDI**
# * Vencimento: **90 dias**
#
# 📌 IR: 22,5% (ok, custo tático)
#
# ---

# %% [markdown]
# ## 🏗️ 2️- LCI pós-fixada (núcleo defensivo)

# %% [markdown]
# #### 📌 Função

# %% [markdown]
# * Segurança máxima
# * Isenção de IR
# * Base de rendimento

# %% [markdown]
# #### 🔢 Estrutura sugerida

# %% [markdown]
# * **2 bancos**
# * R$ 120.000 cada
# * Taxa alvo: **90%–95% do CDI**
# * Prazo: 12–24 meses
# * Liquidez após carência
#
# ---

# %% [markdown]
# ## 🌾 3️- LCA (pós-fixada ou híbrida)

# %% [markdown]
# #### 📌 Função

# %% [markdown]
# * Retorno líquido maior
# * Proteção inflacionária (se híbrida)
# * Complemento ao núcleo

# %% [markdown]
# #### 🔢 Opção A — LCA pós-fixada

# %% [markdown]
# * 95%–100% CDI
# * Prazo: 12–24 meses

# %% [markdown]
# #### 🔢 Opção B — LCA IPCA+

# %% [markdown]
# * IPCA + 5% a 6%
# * Prazo: 3–5 anos
# * Manter até o vencimento
#
# 📌 Escolha conforme:
#
# * **juros altos/subindo → pós**
# * **juros caindo/inflação estrutural → híbrida**
#
# ---

# %% [markdown]
# ## 🛡️ Controle do FGC (CRÍTICO)

# %% [markdown]
# Exemplo de distribuição:
#
# | Banco   | Produto | Valor   |
# | ------- | ------- | ------- |
# | Banco A | CDB     | R$ 75k  |
# | Banco B | CDB     | R$ 75k  |
# | Banco C | LCI     | R$ 120k |
# | Banco D | LCI     | R$ 120k |
# | Banco E | LCA     | R$ 210k |
#
# ✔ Nenhum banco acima de **R$ 250k**
#
# ---

# %% [markdown]
# ## 🔁 Estratégia de rolagem do CDB (o pulo do gato)

# %% [markdown]
# A cada **3 meses**:

# %% [markdown]
# #### Cenário 1 — Juros subiram

# %% [markdown]
# ➡️ Reinvestir CDB em taxa maior

# %% [markdown]
# #### Cenário 2 — Juros caíram

# %% [markdown]
# ➡️ Migrar parte do CDB para:
#
# * LCI/LCA prefixada
# * LCI/LCA híbrida

# %% [markdown]
# #### Cenário 3 — Tudo igual

# %% [markdown]
# ➡️ Renovar CDB curto
#
# 📌 O CDB funciona como **volante de ajuste** da carteira.
#
# ---

# %% [markdown]
# ## 📊 Retorno esperado (ordem de grandeza)

# %% [markdown]
# * LCI/LCA: ~**90–100% CDI líquido**
# * CDB curto (líquido): ~**95–105% CDI**
# * Carteira combinada: **~95–100% CDI líquido**
#
# Com:
#
# * mais segurança
# * menos risco
# * mais flexibilidade
#
# ---

# %% [markdown]
# ## ⚠️ Erros a evitar

# %% [markdown]
# ❌ Concentrar tudo em um banco
# ❌ Ignorar prazo do FGC
# ❌ Usar CDB longo (perde a lógica)
# ❌ Sacar LCI/LCA antes da carência
#
# ---

# %% [markdown]
# ## ✅ Conclusão

# %% [markdown]
# Essa estratégia:
#
# * **não depende de timing perfeito**
# * **sobrevive a qualquer ciclo de juros**
# * maximiza retorno **líquido**
# * mantém **controle total de risco**
#
# Se quiser, posso:
#
# * adaptar para **renda mensal**
# * simular **queda ou alta forte da Selic**
# * incluir **prefixados no timing certo**
# * transformar isso num **plano de longo prazo**
#
# Só me diga o próximo passo.

# %% [markdown]
# # Simulação

# %%
url = 'https://apprendafixa.com.br/app/investimentos/rendafixa?tipo=ALL&fgc=true&vencimentoInicio=1&vencimentoFim=180&irInicio=0&irFim=0.225&riscoInicio=0&riscoFim=1'

gbr_invest = GabrielInvestimentos(url)
gbr_invest.rendimentos.calcular_rendimentos(200)
# Out:
#                                                  Banco Tipo_contrato  \
# 1                                  BANCO GUANABARA S/A           CDB
# 0                                      NEON FINANCEIRA           CDB
# 4                                 BANCO GUANABARA S.A.           CDB
# 3                                 BANCO GUANABARA S.A.           CDB
# 2                                  BANCO GUANABARA S/A           CDB
# 12                                           WILL BANK           CDB
# 11                                        OMNI S/A CFI           CDB
# 5                                      NEON FINANCEIRA           CDB
# 18                                              PICPAY           CDB
# 15                                              PICPAY           CDB
# 9                                               PARANA           CDB
# 10                                        OMNI S/A CFI           CDB
# 7                                  BANCO GUANABARA S/A           CDB
# 24                                       BANCO TOPAZIO           CDB
# 8                                  SOROCRED FINANCEIRA           CDB
# 22                                     NEON FINANCEIRA           CDB
# 27                                   BANCO BTG PACTUAL           CDB
# 25                                   BANCO BTG PACTUAL           CDB
# 26                                   BANCO BTG PACTUAL           CDB
# 34                                      BANCO DAYCOVAL           CDB
# 39                                   BANCO BTG PACTUAL           CDB
# 38                                   BANCO BTG PACTUAL           CDB
# 40                                   BANCO BTG PACTUAL           CDB
# 42                                        PARANA BANCO           CDB
# 45                                   BANCO BTG PACTUAL           CDB
# 44                                   BANCO BTG PACTUAL           CDB
# 46                                   BANCO BTG PACTUAL           CDB
# 54                                      BANCO DAYCOVAL           CDB
# 56                                 BANCO GUANABARA S/A           CDB
# 87                                               PORTO           CDB
# 60                                   BANCO BTG PACTUAL           CDB
# 59                                   BANCO BTG PACTUAL           CDB
# 58                                   BANCO BTG PACTUAL           CDB
# 99                                           BANCO PAN           CDB
# 62                                      BANCO BRADESCO           CDB
# 66                                   BANCO BTG PACTUAL           CDB
# 67                                   BANCO BTG PACTUAL           CDB
# 64                                   BANCO BTG PACTUAL           CDB
# 23                           STELLANTIS F S C F E I SA           CDB
# 101                               BANCO GUANABARA S.A.           CDB
# 71                                           BANCO RNX           CDB
# 100                                      BANCO TOPAZIO           CDB
# 55                                 BANCO GUANABARA S/A           CDB
# 74                                             PAGBANK           CDB
# 118                                       PARANA BANCO           CDB
# 75                                    BANCO STELLANTIS           CDB
# 17                                              PICPAY           CDB
# 16                                              PICPAY           CDB
# 142                                      MERCADO LIVRE           CDB
# 86                                 BANCO GUANABARA S/A           CDB
# 19                                           NU INVEST           CDB
# 91                                   BANCO BTG PACTUAL           CDB
# 89                                   BANCO BTG PACTUAL           CDB
# 90                                           BANCO PAN           CDB
# 113                                   BANCO ABC BRASIL           CDB
# 115                              BANCO DA CHINA BRASIL           CDB
# 111                                     BANCO DAYCOVAL           CDB
# 119                                  BANCO BTG PACTUAL           CDB
# 122                                          BANCO PAN           CDB
# 112                                     BANCO DAYCOVAL           CDB
# 114                                   BANCO ABC BRASIL           CDB
# 79                             BANCO C6 CONSIGNADO S.A           CDB
# 80                                        PARANA BANCO           CDB
# 81                                      BANCO DAYCOVAL           CDB
# 208                                   BANCO ABC BRASIL           CDB
# 20                                              PICPAY           CDB
# 21                                              PICPAY           CDB
# 164                                  BANCO BTG PACTUAL           CDB
# 104                                           BANCO BV           CDB
# 43   PEFISA S.A. - CR?DITO, FINANCIAMENTO E INVESTI...           CDB
# 137                                   BANCO ABC BRASIL           CDB
# 133                            GOLDMAN SACHS DO BRASIL           CDB
# 84                               BANCO VOLKSWAGEN S.A.           CDB
# 217                                           BANCO BV           CDB
# 88                                     BANCO CARREFOUR           CDB
# 6                                  BANCO GUANABARA S/A           CDB
# 159                                      BANCO TOPAZIO           CDB
# 169                                     BANCO DAYCOVAL           CDB
# 158                                           OURIBANK           CDB
# 28                                   BANCO BTG PACTUAL           CDB
# 30                                   BANCO BTG PACTUAL           CDB
# 29                                   BANCO BTG PACTUAL           CDB
# 181                                            PAGBANK           CDB
# 238                                     BANCO DAYCOVAL           CDB
# 263                    BANCO INDUSTRIAL DO BRASIL S/A.           CDB
# 183                                       PARANA BANCO           CDB
# 198                              BANCO DA CHINA BRASIL           CDB
# 31                                   BANCO BTG PACTUAL           CDB
# 32                                   BANCO BTG PACTUAL           CDB
# 33                                   BANCO BTG PACTUAL           CDB
# 121                          STELLANTIS FINANCIAMENTOS           CDB
# 123                                      MERCADO LIVRE           CDB
# 124                                 BCO VOLKSWAGEN S/A           CDB
# 53                 QISTA S.A. - CREDITO, FINANCIAMENTO           CDB
# 141                                          BANCO PAN           CDB
# 57                                        PARANA BANCO           CDB
# 51                      BANCO FIBRA S.A AGENCIA MATRIZ           CDB
# 146                                     BANCO DAYCOVAL           CDB
# 148                                     BANCO DAYCOVAL           CDB
# 204                                            PAGBANK           CDB
# 41                                      BANCO DAYCOVAL           CDB
# 150                                   BANCO VOLKSWAGEN           CDB
# 65                                      BANCO DAYCOVAL           CDB
# 52                           STELLANTIS F S C F E I SA           CDB
# 61                                      BANCO DAYCOVAL           CDB
# 50                 QISTA S.A. - CREDITO, FINANCIAMENTO           CDB
# 174                                          BANCO RNX           CDB
# 173                                       PARANA BANCO           CDB
# 177                                     BANCO DAYCOVAL           CDB
# 231                                     BANCO RODOBENS           CDB
# 179                                     BANCO DAYCOVAL           CDB
# 185                                     BANCO DAYCOVAL           CDB
# 73                                        PARANA BANCO           CDB
# 189                                   BANCO ABC BRASIL           CDB
# 77                                    BANCO STELLANTIS           CDB
# 76                                        PARANA BANCO           CDB
# 116                                          BANCO PAN           CDB
# 199                                  BANCO BTG PACTUAL           CDB
# 200                          STELLANTIS FINANCIAMENTOS           CDB
# 202                                          BANCO BBC           CDB
# 82                                             PAGBANK           CDB
# 210                          STELLANTIS F S C F E I SA           CDB
# 139                                       PARANA BANCO           CDB
# 35                                   BANCO BTG PACTUAL           CDB
# 37                                   BANCO BTG PACTUAL           CDB
# 36                                   BANCO BTG PACTUAL           CDB
# 93                                           BANCO PAN           CDB
# 241                                          BANCO PAN           CDB
# 218                                     BANCO DAYCOVAL           CDB
# 219                                           BANCO BV           CDB
# 83                                    BANCO STELLANTIS           CDB
# 151                                       PARANA BANCO           CDB
# 221                                          BANCO PAN           CDB
# 223                                  BANCO BTG PACTUAL           CDB
# 222                                          BANCO PAN           CDB
# 224                                  BANCO BTG PACTUAL           CDB
# 157                                      MERCADO LIVRE           CDB
# 167                                      MERCADO LIVRE           CDB
# 168                                       PARANA BANCO           CDB
# 229                                          BANCO PAN           CDB
# 227                                  BANCO BTG PACTUAL           CDB
# 235                                     BANCO RODOBENS           CDB
# 97                                   BANCO BTG PACTUAL           CDB
# 98                                             PAGBANK           CDB
# 92                                 BANCO GUANABARA S/A           CDB
# 102                                     BANCO DAYCOVAL           CDB
# 103                                      MERCADO LIVRE           CDB
# 63                                      BANCO DAYCOVAL           CDB
# 110                                     BANCO DAYCOVAL           CDB
# 72                                        PARANA BANCO           CDB
# 108                              BANCO VOLKSWAGEN S.A.           CDB
# 147                            GOLDMAN SACHS DO BRASIL           CDB
# 240                                       PARANA BANCO           CDB
# 109                                     BANCO DAYCOVAL           CDB
# 107                                     BANCO DAYCOVAL           CDB
# 242                                   BANCO ABC BRASIL           CDB
# 135                                     BANCO DAYCOVAL           CDB
# 131                                     BANCO DAYCOVAL           CDB
# 128                                     BANCO DAYCOVAL           CDB
# 156                                           OURIBANK           CDB
# 132                          STELLANTIS FINANCIAMENTOS           CDB
# 149                            GOLDMAN SACHS DO BRASIL           CDB
# 143                                     BANCO DAYCOVAL           CDB
# 126                                  BANCO BTG PACTUAL           CDB
# 211                                           OURIBANK           CDB
# 129                          STELLANTIS FINANCIAMENTOS           CDB
# 134                          STELLANTIS FINANCIAMENTOS           CDB
# 117                                           BANCO BV           CDB
# 166                                           OURIBANK           CDB
# 138                                     BANCO DAYCOVAL           CDB
# 130                                     BANCO DAYCOVAL           CDB
# 145                                     BANCO DAYCOVAL           CDB
# 193                                  BANCO BTG PACTUAL           CDB
# 171                                       PARANA BANCO           CDB
# 152                                       PARANA BANCO           CDB
# 85                                    BANCO STELLANTIS           CDB
# 106                                          BANCO PAN           CDB
# 251                                 BANCO OURIBANK S.A           CDB
# 170                                     BANCO DAYCOVAL           CDB
# 253                                  BANCO BTG PACTUAL           CDB
# 178                                       PARANA BANCO           CDB
# 96                                           BANCO PAN           CDB
# 95                                   BANCO BTG PACTUAL           CDB
# 175                                  BANCO BTG PACTUAL           CDB
# 176                                          BANCO PAN           CDB
# 254                                   BANCO ABC BRASIL           CDB
# 255                                           BANCO BV           CDB
# 194                                     BANCO DAYCOVAL           CDB
# 184                                       PARANA BANCO           CDB
# 187                                     BANCO DAYCOVAL           CDB
# 182                                          BANCO PAN           CDB
# 155                            GOLDMAN SACHS DO BRASIL           CDB
# 163                                           OURIBANK           CDB
# 180                                  BANCO BTG PACTUAL           CDB
# 197                                       PARANA BANCO           CDB
# 190                                     BANCO DAYCOVAL           CDB
# 257                                    BANCO OURINVEST           CDB
# 172                                     BANCO DAYCOVAL           CDB
# 188                                     BANCO DAYCOVAL           CDB
# 195                                       PARANA BANCO           CDB
# 192                                     BANCO DAYCOVAL           CDB
# 186                                       PARANA BANCO           CDB
# 196                                       PARANA BANCO           CDB
# 105                                            PAGBANK           CDB
# 245                                     BANCO DAYCOVAL           CDB
# 191                                     BANCO DAYCOVAL           CDB
# 244                                     BANCO DAYCOVAL           CDB
# 201                                          BANCO PAN           CDB
# 262                                     BANCO RODOBENS           CDB
# 207                                       PARANA BANCO           CDB
# 203                                     BANCO DAYCOVAL           CDB
# 206                                  BANCO BTG PACTUAL           CDB
# 120                                           BANCO BV           CDB
# 205                                       PARANA BANCO           CDB
# 220                                       PARANA BANCO           CDB
# 209                                     BANCO DAYCOVAL           CDB
# 136                                     BANCO DAYCOVAL           CDB
# 264                                           OURIBANK           CDB
# 228                              BANCO DA CHINA BRASIL           CDB
# 49                                   BANCO BTG PACTUAL           CDB
# 47                                   BANCO BTG PACTUAL           CDB
# 48                                   BANCO BTG PACTUAL           CDB
# 226                                           BANCO BV           CDB
# 144                                          BANCO PAN           CDB
# 233                                  BANCO BTG PACTUAL           CDB
# 232                                  BANCO BTG PACTUAL           CDB
# 265                                   BANCO ABC BRASIL           CDB
# 236                                           BANCO BV           CDB
# 234                                     BANCO DAYCOVAL           CDB
# 154                              BANCO DA CHINA BRASIL           CDB
# 78                                     NEON FINANCEIRA           CDB
# 230                                     BANCO RODOBENS           CDB
# 161                                     BANCO DAYCOVAL           CDB
# 239                                     BANCO DAYCOVAL           CDB
# 247                                     BANCO RODOBENS           CDB
# 215                                     BANCO DAYCOVAL           CDB
# 212                            GOLDMAN SACHS DO BRASIL           CDB
# 216                                      MERCADO LIVRE           CDB
# 249                                     BANCO DAYCOVAL           CDB
# 252                                           OURIBANK           CDB
# 259                                    BANCO OURINVEST           CDB
# 162                                     BANCO DAYCOVAL           CDB
# 258                                    BANCO OURINVEST           CDB
# 256                                           OURIBANK           CDB
# 261                                           OURIBANK           CDB
# 260                                    BANCO OURINVEST           CDB
# 213                              BANCO DA CHINA BRASIL           CDB
# 246                                     BANCO DAYCOVAL           CDB
# 248                              BANCO DA CHINA BRASIL           CDB
# 267                                          BANCO CCB           LCA
# 268                                   BANCO ABC BRASIL           LCA
# 269                                   BANCO ABC BRASIL           LCA
# 266                                           OURIBANK           CDB
# 270                                   BANCO ABC BRASIL           LCA
# 271                                   BANCO ABC BRASIL           LCA
# 214                                     BANCO DAYCOVAL           CDB
# 94                                    BANCO STELLANTIS           CDB
# 160                                          BANCO PAN           CDB
# 272                                  BANCO BTG PACTUAL           LCA
# 273                                  BANCO BTG PACTUAL           LCA
# 274                                  BANCO BTG PACTUAL           LCA
# 125                                          BANCO PAN           CDB
# 127                                            PAGBANK           CDB
# 165                                     BANCO DAYCOVAL           CDB
# 153                                     BANCO DAYCOVAL           CDB
# 275                                             SICOOB           LCA
# 237                                      MERCADO LIVRE           CDB
# 243                                     BANCO DAYCOVAL           CDB
# 277                                  BANCO BTG PACTUAL           LCA
# 225                              BANCO DA CHINA BRASIL           CDB
# 276                                   BANCO ABC BRASIL           LCI
# 278                                  BANCO BTG PACTUAL           LCA
# 250                              BANCO DA CHINA BRASIL           CDB
# 282                                  BANCO BTG PACTUAL           LCA
# 283                                  BANCO BTG PACTUAL           LCA
# 279                                   BANCO ABC BRASIL           LCA
# 281                                    BANCO BOCOM BBM           LCA
# 280                                                BBM           LCA
# 284                                    BANCO BOCOM BBM           LCA
# 285                                   BANCO ABC BRASIL           LCA
# 286                                  BANCO BTG PACTUAL           LCA
# 287                AGROLEND SOCIEDADE DE CREDITO, FINA           LCA
# 288                                  BANCO BTG PACTUAL           LCA
# 13                                       BANCO HAITONG           CDB
# 289                                    BANCO BOCOM BBM           LCA
# 14                                            BANCO BV           CDB
# 290                                    BANCO BOCOM BBM           LCA
# 291                                  BANCO BTG PACTUAL           LCA
# 292                                             PICPAY           CDB
# 293                                             PICPAY           CDB
# 70                            BANCO C6 CONSIGNADO S.A.           CDB
# 68                      BANCO FIBRA S.A AGENCIA MATRIZ           CDB
# 69                                        PARANA BANCO           CDB
# 140                     BR PARTNERS BANCO DE INVESTIME           CDB
#
#       Taxa_tipo   Taxa%  Vencimento  Valor_inicial  Valor_bruto       IR  \
# 1       CDI_PCT  112.00         196         200000    217783.52  3556.70
# 0       CDI_PCT  112.00         182         200000    216443.33  3288.67
# 4       CDI_PCT  112.50         225         200000    220409.52  4081.90
# 3       CDI_PCT  112.50         228         200000    220678.72  4135.74
# 2       CDI_PCT  112.00         219         200000    219646.09  3929.22
# 12          PRE   16.40         192         200000    216632.23  3326.45
# 11          PRE   16.40         184         200000    215912.37  3182.47
# 5       CDI_PCT  110.00         154         200000    213533.37  3045.01
# 18      CDI_PCT  105.00         181         200000    215252.83  3050.57
