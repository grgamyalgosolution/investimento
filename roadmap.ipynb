# %% [markdown]
# # 🧠 MAPA MATEMÁTICO DOS INVESTIMENTOS EM RENDA FIXA

# %% [markdown]
# ## 1️- Matemática Financeira (núcleo absoluto)

# %% [markdown]
# 📌 **Área:** Matemática Aplicada
# 📌 **Nível:** Graduação inicial

# %% [markdown]
# ### Tópicos fundamentais

# %% [markdown]
# * Juros simples vs compostos
# * Taxas equivalentes
# * Capitalização discreta e contínua
# * Descontos
# * Valor presente (VP) e valor futuro (VF)
# * Séries de pagamentos

# %% [markdown]
# ### Aplica-se a:

# %% [markdown]
# | Produto    | Uso                               |
# | ---------- | --------------------------------- |
# | CDB pré    | capitalização composta            |
# | %CDI       | taxa equivalente                  |
# | CDI spread | composição multiplicativa         |
# | IPCA+      | decomposição inflação × juro real |
#
# 📘 Livros:
#
# * **Assaf Neto – Matemática Financeira**
# * **Ross, Westerfield, Jaffe – Corporate Finance (cap. iniciais)**
#
# ---

# %% [markdown]
# ## 2️- Teoria das Taxas de Juros (Yield Curves)

# %% [markdown]
# 📌 **Área:** Finanças Matemáticas
# 📌 **Nível:** Graduação → Pós
#
# Aqui você sai do “juros único” e entra no **tempo como dimensão**.

# %% [markdown]
# ### Tópicos

# %% [markdown]
# * Estrutura a termo da taxa de juros
# * Taxa spot, forward, zero-coupon
# * Curvas prefixada, real e nominal
# * Bootstrapping

# %% [markdown]
# ### Aplica-se a:

# %% [markdown]
# | Produto   | Uso                          |
# | --------- | ---------------------------- |
# | CDB longo | comparação entre vencimentos |
# | IPCA+     | juro real implícito          |
# | CDI       | taxa overnight acumulada     |
# | NTN-B     | benchmark correto            |
#
# 📘 Livros:
#
# * **Fabozzi – Fixed Income Mathematics**
# * **Martellini – Fixed Income Securities**
#
# ---

# %% [markdown]
# ## 3️- Análise de Séries Temporais

# %% [markdown]
# 📌 **Área:** Estatística / Probabilidade
# 📌 **Nível:** Graduação → Pós
#
# Tudo que envolve **CDI diário, IPCA mensal, Selic** é série temporal.

# %% [markdown]
# ### Tópicos

# %% [markdown]
# * Retornos logarítmicos
# * Agregação temporal
# * Média geométrica vs aritmética
# * Estacionariedade
# * Defasagens (lags)

# %% [markdown]
# ### Aplica-se a:

# %% [markdown]
# | Tema          | Uso                |
# | ------------- | ------------------ |
# | CDI diário    | produto de fatores |
# | IPCA defasado | lag estrutural     |
# | Focus         | projeções          |
#
# 📘 Livros:
#
# * **Tsay – Analysis of Financial Time Series**
# * **Hamilton – Time Series Analysis**
#
# ---

# %% [markdown]
# ## 4️- Probabilidade e Estatística Matemática

# %% [markdown]
# 📌 **Área:** Matemática Pura / Estatística
# 📌 **Nível:** Graduação sólida
#
# Você usa isso quando:
#
# * compara retornos
# * decide prazos
# * avalia risco

# %% [markdown]
# ### Tópicos

# %% [markdown]
# * Variáveis aleatórias
# * Esperança, variância
# * Distribuições (normal, lognormal)
# * Inferência
# * Intervalos de confiança

# %% [markdown]
# ### Aplica-se a:

# %% [markdown]
# | Tema                    | Uso             |
# | ----------------------- | --------------- |
# | Rentabilidade           | expectativa     |
# | IPCA futuro             | incerteza       |
# | CDI                     | variância baixa |
# | Risco de reinvestimento | probabilidade   |
#
# 📘 Livros:
#
# * **Casella & Berger – Statistical Inference**
# * **Sheldon Ross – Probability Models**
#
# ---

# %% [markdown]
# ## 5️- Cálculo Diferencial e Integral

# %% [markdown]
# 📌 **Área:** Matemática Pura
# 📌 **Nível:** Graduação
#
# Você não percebe, mas ele está ali.

# %% [markdown]
# ### Tópicos

# %% [markdown]
# * Exponenciais e logaritmos
# * Taxa instantânea
# * Capitalização contínua
# * Aproximações

# %% [markdown]
# ### Aplica-se a:

# %% [markdown]
# | Tema                   | Uso       |
# | ---------------------- | --------- |
# | Taxas equivalentes     | log / exp |
# | CDI contínuo           | limite    |
# | Sensibilidade de taxas | derivadas |
#
# 📘 Livros:
#
# * **Stewart – Calculus**
# * **Apostol – Calculus**
#
# ---

# %% [markdown]
# ## 6️- Álgebra Linear (menos óbvio, mas essencial)

# %% [markdown]
# 📌 **Área:** Matemática Pura
# 📌 **Nível:** Graduação
#
# Surge quando você:
#
# * constrói carteiras
# * faz simulações
# * otimiza retorno × prazo

# %% [markdown]
# ### Tópicos

# %% [markdown]
# * Vetores e matrizes
# * Espaços vetoriais
# * Autovalores
# * Otimização quadrática

# %% [markdown]
# ### Aplica-se a:

# %% [markdown]
# | Tema                 | Uso        |
# | -------------------- | ---------- |
# | Comparação de ativos | vetores    |
# | Portfólio de CDBs    | combinação |
# | Sensibilidade        | matrizes   |
#
# 📘 Livros:
#
# * **Strang – Linear Algebra**
# * **Boyd & Vandenberghe – Convex Optimization**
#
# ---

# %% [markdown]
# ## 7️- Finanças Matemáticas Estocásticas (nível avançado)

# %% [markdown]
# 📌 **Área:** Matemática Aplicada
# 📌 **Nível:** Pós-graduação
#
# Não é essencial para CDB simples, mas **fecha o ciclo teórico**.

# %% [markdown]
# ### Tópicos

# %% [markdown]
# * Processos estocásticos
# * Movimento Browniano
# * Modelos de taxa de juros (Vasicek, CIR)
# * Medida neutra ao risco

# %% [markdown]
# ### Aplica-se a:

# %% [markdown]
# | Tema             | Uso       |
# | ---------------- | --------- |
# | Curva CDI futura | simulação |
# | IPCA implícito   | modelos   |
# | Precificação     | rigor     |
#
# 📘 Livros:
#
# * **Shreve – Stochastic Calculus for Finance**
# * **Brigo & Mercurio – Interest Rate Models**
#
# ---
#
# # 🧩 COMO ISSO MAPEA DIRETAMENTE PARA O SEU CÓDIGO
#
# | Seu código                 | Área matemática                 |
# | -------------------------- | ------------------------------- |
# | `(1 + taxa) ** (dias/365)` | Matemática Financeira + Cálculo |
# | Produto do CDI diário      | Séries Temporais                |
# | IPCA defasado              | Estatística + Economia          |
# | %CDI                       | Taxas equivalentes              |
# | Spread CDI                 | Juros reais                     |
# | Ranking por vencimento     | Otimização                      |
#
# ---
#
# # 🎓 ROTEIRO DE ESTUDO SUGERIDO (12 meses)
#
# 1️⃣ Matemática Financeira (3 meses)
# 2️⃣ Cálculo + Log/Exp (2 meses)
# 3️⃣ Probabilidade e Estatística (3 meses)
# 4️⃣ Séries Temporais (2 meses)
# 5️⃣ Renda Fixa / Curvas (2 meses)
#
# 👉 **Isso te coloca acima de 90% dos devs financeiros.**
#
# ---
#
# ## 🧠 Conclusão
#
# Se você dominar:
#
# * Matemática Financeira
# * Estatística
# * Séries Temporais
# * Teoria das Taxas
#
# Você **não depende de calculadora de site** —
# você **constrói a sua**, e sabe **por que ela funciona**.
